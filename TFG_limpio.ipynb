# %% [markdown]
# PASO INICIAL

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importamos el dataset de monthly en crudo

# %%
df = pd.read_csv("/content/drive/MyDrive/TFG-Informatica/Spain-torrevieja_Monthly_Match_2023-11-23.csv")
dataframe_por_meses = pd.DataFrame(df)
dataframe_por_meses
# Out:
# <ipython-input-158-b1ec777ed3c9>:1: DtypeWarning: Columns (24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/drive/MyDrive/TFG-Informatica/Spain-torrevieja_Monthly_Match_2023-11-23.csv")
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 450936             ha-98912ha         Villa  Entire home/apt         2
# 450937             ha-98912ha         Villa  Entire home/apt         2
# 450938             ha-98912ha         Villa  Entire home/apt         2
# ...

# %% [markdown]
# Ahora hacemos la limpieza de columnas

# %%
del dataframe_por_meses['Metropolitan Statistical Area']

# %%
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 450936             ha-98912ha         Villa  Entire home/apt         2
# 450937             ha-98912ha         Villa  Entire home/apt         2
# 450938             ha-98912ha         Villa  Entire home/apt         2
# 450939             ha-98912ha         Villa  Entire home/apt         2
# 450940             ha-98912ha         Villa  Entire home/apt         2
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
del dataframe_por_meses['Zipcode']
del dataframe_por_meses['Neighborhood']
del dataframe_por_meses['Country']
del dataframe_por_meses['State']
del dataframe_por_meses['City']
del dataframe_por_meses['Scraped During Month']
del dataframe_por_meses['HomeAway Property Manager']

# %%
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 450936             ha-98912ha         Villa  Entire home/apt         2
# 450937             ha-98912ha         Villa  Entire home/apt         2
# 450938             ha-98912ha         Villa  Entire home/apt         2
# 450939             ha-98912ha         Villa  Entire home/apt         2
# 450940             ha-98912ha         Villa  Entire home/apt         2
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
del dataframe_por_meses['Currency Native']

# %%
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 450936             ha-98912ha         Villa  Entire home/apt         2
# 450937             ha-98912ha         Villa  Entire home/apt         2
# 450938             ha-98912ha         Villa  Entire home/apt         2
# 450939             ha-98912ha         Villa  Entire home/apt         2
# 450940             ha-98912ha         Villa  Entire home/apt         2
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %% [markdown]
# Hasta aquí la limpieza de columnas, ahora nos quedamos solo con datos de Airbnb y quitamos alguna columna más que solo haga referencia a HomeAway

# %%
dataframe_por_meses = dataframe_por_meses[dataframe_por_meses['Property ID'].str.startswith('ab')]
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
del dataframe_por_meses['HomeAway Property ID']

# %%
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %% [markdown]
# Hasta aquí nuestro dataset por meses ya limpio

# %%
df_prop = pd.read_csv("/content/drive/MyDrive/TFG-Informatica/Spain-torrevieja_Property_Extended_Match_2023-11-23.csv")
# Out:
# <ipython-input-168-ef7ca50eedc7>:1: DtypeWarning: Columns (51,59,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_prop = pd.read_csv("/content/drive/MyDrive/TFG-Informatica/Spain-torrevieja_Property_Extended_Match_2023-11-23.csv")

# %% [markdown]
# Nuestro dataset de properties en crudo

# %%
dataframe_properties = pd.DataFrame(df_prop)
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 16191           ha-9822197ha
# 16192             ha-984234a
# 16193             ha-984827a
# 16194           ha-9856592ha
# 16195             ha-98912ha
#
#                                            Listing Title  Property Type  \
# 0          Stunning apartment in Torrevieja with kitchen    Rental unit
# 1       Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                       Precioso alojamiento con terraza  Vacation home
# 3           Precioso apartamento en complejo residencial          Condo
# 4                       ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                  ...            ...
# 16191                                 Apartmento Baltico      Apartment
# ...

# %%
del dataframe_properties['Zipcode']
del dataframe_properties['Neighborhood']
del dataframe_properties['Metropolitan Statistical Area']
del dataframe_properties['Currency Native']
del dataframe_properties['Country']
del dataframe_properties['State']
del dataframe_properties['City']
del dataframe_properties['HomeAway Property Manager ID']

# %%
del dataframe_properties['Listing URL']
del dataframe_properties['Listing Main Image URL']
del dataframe_properties['Listing Images']
del dataframe_properties['Integrated Property Manager']
del dataframe_properties['Airbnb Home Collection']
del dataframe_properties['Airbnb Property Plus']
del dataframe_properties['HomeAway Premier Partner']
del dataframe_properties['License']
del dataframe_properties['Airbnb Host ID']

# %%
del dataframe_properties['Airbnb Property ID']
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 16191           ha-9822197ha
# 16192             ha-984234a
# 16193             ha-984827a
# 16194           ha-9856592ha
# 16195             ha-98912ha
#
#                                            Listing Title  Property Type  \
# 0          Stunning apartment in Torrevieja with kitchen    Rental unit
# 1       Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                       Precioso alojamiento con terraza  Vacation home
# 3           Precioso apartamento en complejo residencial          Condo
# 4                       ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                  ...            ...
# 16191                                 Apartmento Baltico      Apartment
# ...

# %%
dataframe_properties = dataframe_properties[dataframe_properties['Property ID'].str.startswith('ab')]

# %%
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 4                      ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                 ...            ...
# 13665          Великолепная студия на первой линии моря    Rental unit
# ...

# %%
del dataframe_properties['HomeAway Property ID']
del dataframe_properties['HomeAway Location Type']

dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 4                      ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                 ...            ...
# 13665          Великолепная студия на первой линии моря    Rental unit
# ...

# %% [markdown]
# Hasta aquí el dataset de properties preparado

# %% [markdown]
# Ahora vamos a tratar el dataset de daily

# %%
df_daily = pd.read_csv("/content/drive/MyDrive/TFG-Informatica/Spain-torrevieja_Daily_Match_2023-11-23.csv")
dataframe_daily = pd.DataFrame(df_daily)
dataframe_daily
# Out:
# <ipython-input-176-053d1cd80b0d>:1: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_daily = pd.read_csv("/content/drive/MyDrive/TFG-Informatica/Spain-torrevieja_Daily_Match_2023-11-23.csv")
#                      Property ID        Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693  2023-10-01      A         NaN          0.0
# 1         ab-1000454132532105693  2023-10-02      A         NaN          0.0
# 2         ab-1000454132532105693  2023-10-03      A         NaN          0.0
# 3         ab-1000454132532105693  2023-10-04      A         NaN          0.0
# 4         ab-1000454132532105693  2023-10-05      A         NaN          0.0
# ...                          ...         ...    ...         ...          ...
# 13726216            ha-6561883ha  2020-10-04      U         NaN         82.0
# 13726217            ha-6561883ha  2020-10-05      U         NaN         82.0
# ...

# %%
del dataframe_daily['HomeAway Property ID']

# %%
dataframe_daily = dataframe_daily[dataframe_daily['Property ID'].str.startswith('ab')]

# %%
dataframe_daily
# Out:
#                      Property ID        Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693  2023-10-01      A         NaN          0.0
# 1         ab-1000454132532105693  2023-10-02      A         NaN          0.0
# 2         ab-1000454132532105693  2023-10-03      A         NaN          0.0
# 3         ab-1000454132532105693  2023-10-04      A         NaN          0.0
# 4         ab-1000454132532105693  2023-10-05      A         NaN          0.0
# ...                          ...         ...    ...         ...          ...
# 11021374             ab-33353215  2023-10-27      B         NaN        336.0
# 11021375             ab-33353215  2023-10-28      B         NaN        336.0
# 11021376             ab-33353215  2023-10-29      B         NaN        336.0
# 11021377             ab-33353215  2023-10-30      B         NaN        336.0
# 11021378             ab-33353215  2023-10-31      B         NaN        336.0
#
# ...

# %% [markdown]
# Este sería el dataset de daily ya limpio

# %%
del dataframe_daily['Currency Native']

# %%
dataframe_daily
# Out:
#                      Property ID        Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693  2023-10-01      A         NaN          0.0
# 1         ab-1000454132532105693  2023-10-02      A         NaN          0.0
# 2         ab-1000454132532105693  2023-10-03      A         NaN          0.0
# 3         ab-1000454132532105693  2023-10-04      A         NaN          0.0
# 4         ab-1000454132532105693  2023-10-05      A         NaN          0.0
# ...                          ...         ...    ...         ...          ...
# 11021374             ab-33353215  2023-10-27      B         NaN        336.0
# 11021375             ab-33353215  2023-10-28      B         NaN        336.0
# 11021376             ab-33353215  2023-10-29      B         NaN        336.0
# 11021377             ab-33353215  2023-10-30      B         NaN        336.0
# 11021378             ab-33353215  2023-10-31      B         NaN        336.0
#
# ...

# %%
num_property_id_distintos = dataframe_daily['Property ID'].nunique()
num_property_id_distintos
# Out:
# 13589

# %%
num_property_id_distintos_monthly = dataframe_por_meses['Property ID'].nunique()

# %%
num_property_id_distintos_monthly
# Out:
# 13589

# %%
num_distintos_en_properties = dataframe_properties['Property ID'].nunique()

# %%
num_distintos_en_properties
# Out:
# 13670

# %%
diferencias_properties = dataframe_properties[~dataframe_properties['Property ID'].isin(dataframe_por_meses['Property ID'])]
diferencias_properties
# Out:
#                   Property ID  \
# 1896    ab-852287634551352793
# 1962    ab-857272687135530503
# 2007    ab-861288164488423632
# 2789    ab-917464517154105731
# 2909    ab-924060669721993322
# ...                       ...
# 3669   ab-1026461606781437375
# 8684              ab-46270036
# 11184             ab-43923234
# 12146             ab-44886422
# 12699   ab-550819454986418147
#
#                                            Listing Title Property Type  \
# 1896                       Ideal para familias con niños          Home
# 1962                                   K&D Apartment4You   Rental unit
# 2007                                      YourSpain LM3C   Rental unit
# 2789                        Aguas Nuevas Costa del Cezar   Rental unit
# 2909                           083 Casa Pascual con wifi   Rental unit
# ...                                                  ...           ...
# 3669                                            La Playa   Rental unit
# ...

# %%
dataframe_properties = dataframe_properties[~dataframe_properties['Property ID'].isin(diferencias_properties['Property ID'])]
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 4                      ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                 ...            ...
# 13665          Великолепная студия на первой линии моря    Rental unit
# ...

# %%
campos_anyadir = ['Property ID','Listing Title', 'Amenities', 'Overall Rating']
columnas_a_anyadir = dataframe_properties.loc[:, campos_anyadir]

# %%
columnas_a_anyadir
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  \
# 0         Stunning apartment in Torrevieja with kitchen
# 1      Stunning apartment in Torrevieja with 2 Bedrooms
# 2                      Precioso alojamiento con terraza
# 3          Precioso apartamento en complejo residencial
# 4                      ALQUILER VACACIONAL TORREVIEJA!!
# ...                                                 ...
# 13665          Великолепная студия на первой линии моря
# 13666                      Torreviejà Vacances de Rêves
# 13667                                    Punta Prima 13
# ...

# %%
combinado_meses = pd.merge(dataframe_por_meses, columnas_a_anyadir, on='Property ID', how = 'left')
combinado_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado = pd.merge(dataframe_daily, columnas_a_anyadir, on='Property ID', how = 'left')
combinado
# Out:
#                      Property ID        Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693  2023-10-01      A         NaN          0.0
# 1         ab-1000454132532105693  2023-10-02      A         NaN          0.0
# 2         ab-1000454132532105693  2023-10-03      A         NaN          0.0
# 3         ab-1000454132532105693  2023-10-04      A         NaN          0.0
# 4         ab-1000454132532105693  2023-10-05      A         NaN          0.0
# ...                          ...         ...    ...         ...          ...
# 11021374             ab-33353215  2023-10-27      B         NaN        336.0
# 11021375             ab-33353215  2023-10-28      B         NaN        336.0
# 11021376             ab-33353215  2023-10-29      B         NaN        336.0
# 11021377             ab-33353215  2023-10-30      B         NaN        336.0
# 11021378             ab-33353215  2023-10-31      B         NaN        336.0
#
# ...

# %% [markdown]
#   Intentamos crear una tabla intentando agrupar todas las veces que se repite cada mes

# %%
tabla_total_por_meses = dataframe_por_meses['Reporting Month'].value_counts().reset_index()
tabla_total_por_meses.columns = ['Reporting Month', 'Count']
tabla_invertida = tabla_total_por_meses.sort_values(by = 'Reporting Month', ascending = True)
tabla_invertida
# Out:
#    Reporting Month  Count
# 85      2016-09-01   1732
# 84      2016-10-01   1840
# 83      2016-11-01   1937
# 82      2016-12-01   1988
# 81      2017-01-01   2085
# ..             ...    ...
# 4       2023-06-01   6006
# 3       2023-07-01   6234
# 2       2023-08-01   6313
# 1       2023-09-01   6374
# 0       2023-10-01   6389
#
# [86 rows x 2 columns]

# %% [markdown]
# Empezamos a importar las librerias para hacer gráficas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x='Reporting Month', y='Count', data=tabla_invertida, palette='plasma')
plt.title('Recuento de propiedades anunciadas por mes')
plt.xlabel('Mes')
plt.ylabel('Recuento')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-195-d6871901eff6>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Reporting Month', y='Count', data=tabla_invertida, palette='plasma')

# %% [markdown]
# Ahora vamos a hacer una gráfica de la ocupación por meses

# %%
tasa_ocupacion_mes = dataframe_por_meses.groupby('Reporting Month')['Occupancy Rate'].mean().reset_index()
tasa_ocupacion_mes.columns = ['Reporting Month', 'Tasa de ocupación']
tabla_invertida2 = tasa_ocupacion_mes.sort_values(by = 'Reporting Month', ascending = True)
tabla_invertida2
# Out:
#    Reporting Month  Tasa de ocupación
# 0       2016-09-01           0.103174
# 1       2016-10-01           0.118549
# 2       2016-11-01           0.065780
# 3       2016-12-01           0.090508
# 4       2017-01-01           0.069127
# ..             ...                ...
# 81      2023-06-01           0.267553
# 82      2023-07-01           0.407894
# 83      2023-08-01           0.467288
# 84      2023-09-01           0.237255
# 85      2023-10-01           0.193796
#
# [86 rows x 2 columns]

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x='Reporting Month', y='Tasa de ocupación', data=tabla_invertida2, palette='viridis')
plt.title('Tasa de ocupación por mes')
plt.xlabel('Mes')
plt.ylabel('%')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-197-495272e760be>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Reporting Month', y='Tasa de ocupación', data=tabla_invertida2, palette='viridis')

# %%
combinado_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado_meses_filtrado = combinado_meses[(combinado_meses['Active']) & (combinado_meses['Occupancy Rate'] > 0)]
combinado_meses_filtrado
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361764            ab-26982422   Rental unit  Entire home/apt         1
# 361765            ab-26982422   Rental unit  Entire home/apt         1
# 361769            ab-26982422   Rental unit  Entire home/apt         1
# 361773            ab-26982422   Rental unit  Entire home/apt         1
# 361775            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
tasa_ocupacion_mes_clean = combinado_meses_filtrado.groupby('Reporting Month')['Occupancy Rate'].mean().reset_index()
tasa_ocupacion_mes_clean.columns = ['Reporting Month', 'Tasa de ocupación']
tabla_invertida3 = tasa_ocupacion_mes_clean.sort_values(by = 'Reporting Month', ascending = True)
tabla_invertida3
# Out:
#    Reporting Month  Tasa de ocupación
# 0       2016-09-01           0.522509
# 1       2016-10-01           0.526884
# 2       2016-11-01           0.442417
# 3       2016-12-01           0.569399
# 4       2017-01-01           0.471010
# ..             ...                ...
# 81      2023-06-01           0.593398
# 82      2023-07-01           0.758369
# 83      2023-08-01           0.802282
# 84      2023-09-01           0.533804
# 85      2023-10-01           0.556227
#
# [86 rows x 2 columns]

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x='Reporting Month', y='Tasa de ocupación', data=tabla_invertida3, palette='viridis')
plt.title('Tasa de ocupación por mes')
plt.xlabel('Mes')
plt.ylabel('%')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-201-dbdd02a9e346>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Reporting Month', y='Tasa de ocupación', data=tabla_invertida3, palette='viridis')

# %%
combinado_meses_filtrado
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361764            ab-26982422   Rental unit  Entire home/apt         1
# 361765            ab-26982422   Rental unit  Entire home/apt         1
# 361769            ab-26982422   Rental unit  Entire home/apt         1
# 361773            ab-26982422   Rental unit  Entire home/apt         1
# 361775            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 4                      ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                 ...            ...
# 13665          Великолепная студия на первой линии моря    Rental unit
# ...

# %%
num_prop_por_habitacion = dataframe_properties['Bedrooms'].value_counts().reset_index()
num_prop_por_habitacion.columns = ['Bedrooms', 'Count']
num_prop_por_habitacion
# Out:
#    Bedrooms  Count
# 0         2   7011
# 1         1   3346
# 2         3   2237
# 3         0    644
# 4         4    257
# 5         5     57
# 6         6     28
# 7         7      7
# 8         8      1
# 9        14      1

# %%
tabla_invertida4 = num_prop_por_habitacion.sort_values(by = 'Bedrooms', ascending = True)
tabla_invertida4
# Out:
#    Bedrooms  Count
# 3         0    644
# 1         1   3346
# 0         2   7011
# 2         3   2237
# 4         4    257
# 5         5     57
# 6         6     28
# 7         7      7
# 8         8      1
# 9        14      1

# %%
tabla_invertida4 = tabla_invertida4.drop(7)
tabla_invertida4 = tabla_invertida4.drop(8)
tabla_invertida4 = tabla_invertida4.drop(9)

# %%
tabla_invertida4
# Out:
#    Bedrooms  Count
# 3         0    644
# 1         1   3346
# 0         2   7011
# 2         3   2237
# 4         4    257
# 5         5     57
# 6         6     28

# %%
plt.figure(figsize=(10, 6))

plt.bar(tabla_invertida4['Bedrooms'], tabla_invertida4['Count'], width=0.6, align='center', edgecolor='white', color = 'green' )

plt.title('Distribución de propiedades por número de habitaciones', fontsize=10)
plt.xlabel('Número de habitaciones', fontsize = 9)

plt.xticks(rotation=0)

plt.show()

# %%
num_prop_por_bath = dataframe_properties['Bathrooms'].value_counts().reset_index()
num_prop_por_bath.columns = ['Bathrooms', 'Count']
num_prop_por_bath
# Out:
#     Bathrooms  Count
# 0         1.0   9107
# 1         2.0   3037
# 2         1.5    963
# 3         3.0    239
# 4         2.5    131
# 5         0.0     37
# 6         4.0     35
# 7         3.5     17
# 8         5.0      9
# 9         4.5      5
# 10        6.0      4
# 11        5.5      3
# 12        7.0      1
# 13        7.5      1

# %%
tabla_invertida5 = num_prop_por_bath.sort_values(by = 'Bathrooms', ascending = True)
tabla_invertida5
# Out:
#     Bathrooms  Count
# 5         0.0     37
# 0         1.0   9107
# 2         1.5    963
# 1         2.0   3037
# 4         2.5    131
# 3         3.0    239
# 7         3.5     17
# 6         4.0     35
# 9         4.5      5
# 8         5.0      9
# 11        5.5      3
# 10        6.0      4
# 12        7.0      1
# 13        7.5      1

# %%
indices_eliminar = [8, 9, 10, 11, 12, 13]
tabla_invertida5 = tabla_invertida5.drop(indices_eliminar)
tabla_invertida5
# Out:
#    Bathrooms  Count
# 5        0.0     37
# 0        1.0   9107
# 2        1.5    963
# 1        2.0   3037
# 4        2.5    131
# 3        3.0    239
# 7        3.5     17
# 6        4.0     35

# %%
tabla_invertida5 = tabla_invertida5.drop(5)
tabla_invertida5
# Out:
#    Bathrooms  Count
# 0        1.0   9107
# 2        1.5    963
# 1        2.0   3037
# 4        2.5    131
# 3        3.0    239
# 7        3.5     17
# 6        4.0     35

# %%
plt.figure(figsize=(10, 6))

plt.bar(tabla_invertida5['Bathrooms'], tabla_invertida5['Count'], width=0.5, align='center', edgecolor='white', color = 'green' )

plt.title('Distribución de propiedades por número de baños', fontsize=10)
plt.xlabel('Número de baños', fontsize = 9)

plt.xticks(rotation=0)

plt.show()

# %%
tabla_invertida5
# Out:
#    Bathrooms  Count
# 0        1.0   9107
# 2        1.5    963
# 1        2.0   3037
# 4        2.5    131
# 3        3.0    239
# 7        3.5     17
# 6        4.0     35

# %%
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 4                      ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                 ...            ...
# 13665          Великолепная студия на первой линии моря    Rental unit
# ...

# %%
casas_con_parking = dataframe_properties[dataframe_properties['Amenities'].apply(lambda x: 'free_parking' in x)]
casas_con_parking
# Out:
#                  Property ID  \
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 5      ab-605119030776239205
# 6      ab-605635512243513927
# 7      ab-605719787869931071
# ...                      ...
# 13660            ab-24731662
# 13661            ab-34502581
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                            Listing Title  Property Type  \
# 2                       Precioso alojamiento con terraza  Vacation home
# 3           Precioso apartamento en complejo residencial          Condo
# 5             Brand New Apartment. 400 meters Best Beach    Rental unit
# 6                    Standard Plus with Interior Terrace  Room in hotel
# 7      1-bedroom w living room & corner sea-view terrace  Room in hotel
# ...                                                  ...            ...
# 13660                 ESTUDIO 2ª Linea de playa del cura      Apartment
# ...

# %%
casas_sin_parking = 13589-5494
valores = [5494, casas_sin_parking]
etiquetas = ['Con parking', 'Sin parking']
colores = ['#359b1c', '#E84538']

plt.figure(figsize=(8, 6))
plt.pie(valores, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))

# Añadir un círculo en el centro para crear un donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Ajustar el aspecto del gráfico
plt.axis('equal')

# Añadir título
plt.title('Proporción de casas con y sin parking', fontsize=10)

# Mostrar el gráfico
plt.show()

# %%
casas_con_piscina = dataframe_properties[dataframe_properties['Amenities'].apply(lambda x: 'pool' in x)]
casas_con_piscina
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 5      ab-605119030776239205
# ...                      ...
# 13659            ab-24992826
# 13661            ab-34502581
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 5            Brand New Apartment. 400 meters Best Beach    Rental unit
# ...                                                 ...            ...
# 13659                                        Torrevieja      Apartment
# ...

# %%
casas_sin_piscina = 13589-7690
valores = [7690, casas_sin_piscina]
etiquetas = ['Con piscina', 'Sin piscina']
colores = ['#359b1c', '#E84538']

plt.figure(figsize=(8, 6))
plt.pie(valores, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))

# Añadir un círculo en el centro para crear un donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Ajustar el aspecto del gráfico
plt.axis('equal')

# Añadir título
plt.title('Proporción de casas con y sin parking', fontsize=10)

# Mostrar el gráfico
plt.show()

# %%
adr_medio_casas_con_piscina = casas_con_piscina['Average Daily Rate (Native)'].mean()
adr_medio_casas_con_piscina
# Out:
# 114.7335028790787

# %%
casas_sin_piscina = dataframe_properties[~dataframe_properties['Amenities'].apply(lambda x: 'pool' in x)]
casas_sin_piscina
# Out:
#                  Property ID  \
# 4      ab-605108518012999409
# 6      ab-605635512243513927
# 7      ab-605719787869931071
# 10     ab-606452395937214087
# 11     ab-606853966546183345
# ...                      ...
# 13662            ab-22171047
# 13663            ab-41869871
# 13664            ab-45769328
# 13665            ab-37234059
# 13666            ab-38069101
#
#                                            Listing Title       Property Type  \
# 4                       ALQUILER VACACIONAL TORREVIEJA!!         Rental unit
# 6                    Standard Plus with Interior Terrace       Room in hotel
# 7      1-bedroom w living room & corner sea-view terrace       Room in hotel
# 10                                      Dream of the SEA  Serviced apartment
# 11                            Beach Apartment Torrevieja         Rental unit
# ...                                                  ...                 ...
# ...

# %%
adr_medio_casas_sin_piscina = casas_sin_piscina['Average Daily Rate (Native)'].mean()
adr_medio_casas_sin_piscina
# Out:
# 94.50182980599648

# %%
data = [["ADR propiedades con piscina", 114.73], ["ADR propiedades sin piscina", 94.5]]
dataframe_adr = pd.DataFrame(data, columns=['Categoría', 'ADR'])
dataframe_adr
# Out:
#                      Categoría     ADR
# 0  ADR propiedades con piscina  114.73
# 1  ADR propiedades sin piscina   94.50

# %%
plt.figure(figsize=(7, 6))

plt.bar(dataframe_adr['Categoría'], dataframe_adr['ADR'], width=0.5, align='center', edgecolor='white', color = 'green' )

plt.title('Average Daily Rate (euros/noche)', fontsize=10)
plt.xlabel('Categoría', fontsize = 9)

plt.xticks(rotation=0)

plt.show()

# %%
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado_meses_filtrado
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361764            ab-26982422   Rental unit  Entire home/apt         1
# 361765            ab-26982422   Rental unit  Entire home/apt         1
# 361769            ab-26982422   Rental unit  Entire home/apt         1
# 361773            ab-26982422   Rental unit  Entire home/apt         1
# 361775            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
con_piscina_ocupacion_mensual = combinado_meses_filtrado[combinado_meses_filtrado['Amenities'].apply(lambda x: 'pool' in x)]
con_piscina_ocupacion_mensual
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361714            ab-26977145   Rental unit  Entire home/apt         2
# 361715            ab-26977145   Rental unit  Entire home/apt         2
# 361723            ab-26977145   Rental unit  Entire home/apt         2
# 361724            ab-26977145   Rental unit  Entire home/apt         2
# 361725            ab-26977145   Rental unit  Entire home/apt         2
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
sin_piscina_ocupacion_mensual = combinado_meses_filtrado[~combinado_meses_filtrado['Amenities'].apply(lambda x: 'pool' in x)]
sin_piscina_ocupacion_mensual
# Out:
#                   Property ID  Property Type     Listing Type  Bedrooms  \
# 108     ab-605635512243513927  Room in hotel     Private room         1
# 111     ab-605635512243513927  Room in hotel     Private room         1
# 118     ab-605635512243513927  Room in hotel     Private room         1
# 125     ab-605719787869931071  Room in hotel     Private room         1
# 136     ab-605719787869931071  Room in hotel     Private room         1
# ...                       ...            ...              ...       ...
# 361764            ab-26982422    Rental unit  Entire home/apt         1
# 361765            ab-26982422    Rental unit  Entire home/apt         1
# 361769            ab-26982422    Rental unit  Entire home/apt         1
# 361773            ab-26982422    Rental unit  Entire home/apt         1
# 361775            ab-26982422    Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
media_ocupacion_conpis = con_piscina_ocupacion_mensual['Occupancy Rate'].mean()
media_ocupacion_conpis
# Out:
# 0.5804357527857682

# %%
media_ocupacion_sinpis = sin_piscina_ocupacion_mensual['Occupancy Rate'].mean()
media_ocupacion_sinpis
# Out:
# 0.5861257717522755

# %%
data = [["Tasa de ocupación con piscina", 58.04], ["Tasa de ocupación sin piscina", 58.61]]
dataframe_ocupacion_piscina = pd.DataFrame(data, columns=['Categoría', 'Porcentaje'])
dataframe_ocupacion_piscina
# Out:
#                        Categoría  Porcentaje
# 0  Tasa de ocupación con piscina       58.04
# 1  Tasa de ocupación sin piscina       58.61

# %%
plt.figure(figsize=(7, 6))

plt.bar(dataframe_ocupacion_piscina['Categoría'], dataframe_ocupacion_piscina['Porcentaje'], width=0.5, align='center', edgecolor='white', color = 'green' )

plt.title('Tasa media de ocupación mensual %', fontsize=10)


plt.xticks(rotation=0)

plt.show()

# %%
con_piscina_ocupacion_mensual['Reporting Month'] = pd.to_datetime(con_piscina_ocupacion_mensual['Reporting Month'])
con_piscina_ocupacion_mensual_verano = con_piscina_ocupacion_mensual[(con_piscina_ocupacion_mensual['Reporting Month'].dt.month >= 6) & (con_piscina_ocupacion_mensual['Reporting Month'].dt.month <= 8)]
con_piscina_ocupacion_mensual_verano
# Out:
# <ipython-input-234-ec17059d764c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   con_piscina_ocupacion_mensual['Reporting Month'] = pd.to_datetime(con_piscina_ocupacion_mensual['Reporting Month'])
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 12      ab-604957749777772414   Rental unit  Entire home/apt         2
# 13      ab-604957749777772414   Rental unit  Entire home/apt         2
# 14      ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# ...

# %%
sin_piscina_ocupacion_mensual['Reporting Month'] = pd.to_datetime(sin_piscina_ocupacion_mensual['Reporting Month'])
sin_piscina_ocupacion_mensual_verano = sin_piscina_ocupacion_mensual[(sin_piscina_ocupacion_mensual['Reporting Month'].dt.month >= 6) & (sin_piscina_ocupacion_mensual['Reporting Month'].dt.month <= 8)]
sin_piscina_ocupacion_mensual_verano
# Out:
# <ipython-input-235-11cc445d8989>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sin_piscina_ocupacion_mensual['Reporting Month'] = pd.to_datetime(sin_piscina_ocupacion_mensual['Reporting Month'])
#                   Property ID       Property Type     Listing Type  Bedrooms  \
# 108     ab-605635512243513927       Room in hotel     Private room         1
# 118     ab-605635512243513927       Room in hotel     Private room         1
# 125     ab-605719787869931071       Room in hotel     Private room         1
# 136     ab-605719787869931071       Room in hotel     Private room         1
# 180     ab-606452395937214087  Serviced apartment  Entire home/apt         3
# ...

# %%
media_ocupacion_con_piscina_verano = con_piscina_ocupacion_mensual_verano['Occupancy Rate'].mean()
media_ocupacion_con_piscina_verano
# Out:
# 0.7298025193590979

# %%
media_ocupacion_sin_piscina_verano = sin_piscina_ocupacion_mensual_verano['Occupancy Rate'].mean()
media_ocupacion_sin_piscina_verano
# Out:
# 0.7084902880476769

# %%
data = [["Tasa de ocupación con piscina (verano)", 72.98], ["Tasa de ocupación sin piscina (verano)", 70.85]]
dataframe_ocupacion_piscina_verano = pd.DataFrame(data, columns=['Categoría', 'Porcentaje'])
dataframe_ocupacion_piscina_verano
# Out:
#                                 Categoría  Porcentaje
# 0  Tasa de ocupación con piscina (verano)       72.98
# 1  Tasa de ocupación sin piscina (verano)       70.85

# %%
plt.figure(figsize=(7, 6))

plt.bar(dataframe_ocupacion_piscina_verano['Categoría'], dataframe_ocupacion_piscina_verano['Porcentaje'], width=0.5, align='center', edgecolor='white', color = 'green' )

plt.title('Tasa media de ocupación mensual (verano) %', fontsize=10)


plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# DIAS CON MAYOR OCUPACIÓN, EMPEZAREMOS VIENDO QUÉ DIA DE LA SEMANA SE OCUPA MÁS Y SEGUIREMOS CON FESTIVOS CONCRETOS DEL AÑO

# %%
dataframe_daily
# Out:
#                      Property ID        Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693  2023-10-01      A         NaN          0.0
# 1         ab-1000454132532105693  2023-10-02      A         NaN          0.0
# 2         ab-1000454132532105693  2023-10-03      A         NaN          0.0
# 3         ab-1000454132532105693  2023-10-04      A         NaN          0.0
# 4         ab-1000454132532105693  2023-10-05      A         NaN          0.0
# ...                          ...         ...    ...         ...          ...
# 11021374             ab-33353215  2023-10-27      B         NaN        336.0
# 11021375             ab-33353215  2023-10-28      B         NaN        336.0
# 11021376             ab-33353215  2023-10-29      B         NaN        336.0
# 11021377             ab-33353215  2023-10-30      B         NaN        336.0
# 11021378             ab-33353215  2023-10-31      B         NaN        336.0
#
# ...

# %%
dataframe_daily['Date'] = pd.to_datetime(dataframe_daily['Date'])
dataframe_daily['Día de la semana'] = dataframe_daily['Date'].dt.day_name()
dataframe_daily
# Out:
# <ipython-input-241-6a5a23eab5d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_daily['Date'] = pd.to_datetime(dataframe_daily['Date'])
# <ipython-input-241-6a5a23eab5d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_daily['Día de la semana'] = dataframe_daily['Date'].dt.day_name()
#                      Property ID       Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693 2023-10-01      A         NaN          0.0
# ...

# %%
ocupacion_real_daily = dataframe_daily[dataframe_daily['Status']=='R']
ocupacion_real_daily
# Out:
#                      Property ID       Date Status Booked Date  Price (USD)  \
# 112       ab-1001311904372746789 2023-10-20      R  2023-10-19         53.0
# 113       ab-1001311904372746789 2023-10-21      R  2023-10-19         53.0
# 114       ab-1001311904372746789 2023-10-22      R  2023-10-19         53.0
# 115       ab-1001311904372746789 2023-10-23      R  2023-10-15         53.0
# 116       ab-1001311904372746789 2023-10-24      R  2023-10-15         53.0
# ...                          ...        ...    ...         ...          ...
# 11021209             ab-33353215 2023-05-15      R  2023-05-14        344.0
# 11021210             ab-33353215 2023-05-16      R  2023-05-14        344.0
# 11021211             ab-33353215 2023-05-17      R  2023-05-14        344.0
# 11021212             ab-33353215 2023-05-18      R  2023-05-14        344.0
# 11021247             ab-33353215 2023-06-22      R  2023-06-21        458.0
#
# ...

# %%
ocupacion_por_dias_semana = ocupacion_real_daily['Día de la semana'].value_counts().reset_index()
ocupacion_por_dias_semana.columns = ['Día de la semana', 'Count']
ocupacion_por_dias_semana
# Out:
#   Día de la semana   Count
# 0         Saturday  209118
# 1           Friday  205577
# 2         Thursday  198403
# 3           Sunday  193705
# 4          Tuesday  193697
# 5        Wednesday  193580
# 6           Monday  191218

# %%
data = {
    'Día de la semana': ['Saturday', 'Friday', 'Thursday', 'Sunday', 'Tuesday', 'Wednesday', 'Monday'],
    'Count': [209118, 205577, 198403, 193705, 193697, 193580, 191218]
}
df = pd.DataFrame(data)

# Definir el orden deseado de los días de la semana
orden_dias_semana = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Convertir la columna 'Día de la semana' a tipo categoría ordenada
df['Día de la semana'] = pd.Categorical(df['Día de la semana'], categories=orden_dias_semana, ordered=True)

# Ordenar el DataFrame según la columna 'Día de la semana'
df = df.sort_values(by='Día de la semana')

df
# Out:
#   Día de la semana   Count
# 6           Monday  191218
# 4          Tuesday  193697
# 5        Wednesday  193580
# 2         Thursday  198403
# 1           Friday  205577
# 0         Saturday  209118
# 3           Sunday  193705

# %%
plt.figure(figsize=(10, 6))

plt.bar(df['Día de la semana'], df['Count'], width=0.5, align='center', edgecolor='white', color = 'green' )

plt.title('Distribución de la ocupación por días', fontsize=10)
plt.xlabel('Día de la semana', fontsize = 9)

plt.xticks(rotation=0)




plt.show()

# %% [markdown]
# Ahora analizamos los días del año con mayor ocupación

# %%
dataframe_daily
# Out:
#                      Property ID       Date Status Booked Date  Price (USD)  \
# 0         ab-1000454132532105693 2023-10-01      A         NaN          0.0
# 1         ab-1000454132532105693 2023-10-02      A         NaN          0.0
# 2         ab-1000454132532105693 2023-10-03      A         NaN          0.0
# 3         ab-1000454132532105693 2023-10-04      A         NaN          0.0
# 4         ab-1000454132532105693 2023-10-05      A         NaN          0.0
# ...                          ...        ...    ...         ...          ...
# 11021374             ab-33353215 2023-10-27      B         NaN        336.0
# 11021375             ab-33353215 2023-10-28      B         NaN        336.0
# 11021376             ab-33353215 2023-10-29      B         NaN        336.0
# 11021377             ab-33353215 2023-10-30      B         NaN        336.0
# 11021378             ab-33353215 2023-10-31      B         NaN        336.0
#
# ...

# %%
ocupacion_real_daily['Date'] = pd.to_datetime(ocupacion_real_daily['Date'])
ocupacion_real_daily.loc[:, 'day_month'] = ocupacion_real_daily['Date'].dt.strftime('%m-%d')
ocupacion_por_dias_365 = ocupacion_real_daily['day_month'].value_counts().reset_index()
ocupacion_por_dias_365.columns = ['Día del año', 'Count']
ocupacion_por_dias_365 = ocupacion_por_dias_365.sort_values(by = 'Count', ascending = False)
ocupacion_por_dias_365
# Out:
# <ipython-input-247-60d625b635ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ocupacion_real_daily['Date'] = pd.to_datetime(ocupacion_real_daily['Date'])
# <ipython-input-247-60d625b635ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ocupacion_real_daily.loc[:, 'day_month'] = ocupacion_real_daily['Date'].dt.strftime('%m-%d')
#     Día del año  Count
# 0         08-17  11317
# 1         08-12  11269
# 2         08-14  11235
# 3         08-13  11204
# 4         08-11  11163
# ...

# %%
ocupacion_por_dias_365 = ocupacion_por_dias_365.drop(365)
ocupacion_por_dias_365
# Out:
#     Día del año  Count
# 0         08-17  11317
# 1         08-12  11269
# 2         08-14  11235
# 3         08-13  11204
# 4         08-11  11163
# ..          ...    ...
# 360       12-19   1317
# 361       12-11   1309
# 362       12-17   1277
# 363       11-28   1234
# 364       11-29   1222
#
# [365 rows x 2 columns]

# %%
top_dias_ocupacion = ocupacion_por_dias_365.head(20)
top_dias_ocupacion
# Out:
#    Día del año  Count
# 0        08-17  11317
# 1        08-12  11269
# 2        08-14  11235
# 3        08-13  11204
# 4        08-11  11163
# 5        08-18  11139
# 6        08-16  11128
# 7        08-19  11122
# 8        08-10  11095
# 9        08-15  11013
# 10       08-06  10999
# 11       08-09  10983
# 12       08-07  10940
# 13       08-05  10936
# 14       08-08  10911
# 15       08-20  10845
# 16       08-21  10691
# 17       08-04  10552
# 18       08-22  10468
# 19       08-03  10268

# %%
top_dias_ocupacion = top_dias_ocupacion.sort_values(by='Count', ascending=True)
plt.figure(figsize=(10, 6))
plt.barh(top_dias_ocupacion['Día del año'], top_dias_ocupacion['Count'], height=0.5, align='center', edgecolor='white', color='green')  # Intercambia 'Día del año' y 'Count'
plt.title('Días del año con mayor ocupación', fontsize=10)
plt.ylabel('Día del año', fontsize=7)  # Cambia el eje y a 'Día del año'
plt.xlabel('Count', fontsize=7)  # Cambia el eje x a 'Count'

plt.yticks(rotation=0)  # Asegura que las etiquetas del eje y no se roten
plt.xlim(0,15000)

plt.show()

# %%
menos_ocupados = ocupacion_por_dias_365.nsmallest(20, 'Count')
menos_ocupados
# Out:
#     Día del año  Count
# 364       11-29   1222
# 363       11-28   1234
# 362       12-17   1277
# 361       12-11   1309
# 360       12-19   1317
# 359       12-02   1320
# 358       12-01   1335
# 357       12-18   1348
# 356       12-12   1353
# 355       12-16   1356
# 354       12-15   1373
# 353       12-10   1377
# 352       12-14   1384
# 351       12-13   1387
# 350       01-22   1389
# 349       12-20   1402
# 348       11-27   1406
# 346       12-09   1412
# 347       12-03   1412
# 345       11-26   1416

# %%
top_dias_menos_ocupacion = menos_ocupados.sort_values(by='Count', ascending=True)
plt.figure(figsize=(10, 6))
plt.barh(top_dias_menos_ocupacion['Día del año'], top_dias_menos_ocupacion['Count'], height=0.5, align='center', edgecolor='white', color='green')  # Intercambia 'Día del año' y 'Count'
plt.title('Días del año con menor ocupación', fontsize=10)
plt.ylabel('Día del año', fontsize=7)  # Cambia el eje y a 'Día del año'
plt.xlabel('Count', fontsize=7)  # Cambia el eje x a 'Count'

plt.yticks(rotation=0)  # Asegura que las etiquetas del eje y no se roten
plt.xlim(0,1500)

plt.show()

# %%
ocupacion_por_dias_365
# Out:
#     Día del año  Count
# 0         08-17  11317
# 1         08-12  11269
# 2         08-14  11235
# 3         08-13  11204
# 4         08-11  11163
# ..          ...    ...
# 360       12-19   1317
# 361       12-11   1309
# 362       12-17   1277
# 363       11-28   1234
# 364       11-29   1222
#
# [365 rows x 2 columns]

# %%
ocupacion_por_dias_365['Día del año'] = pd.to_datetime(ocupacion_por_dias_365['Día del año'], format='%m-%d')
sin_verano = ocupacion_por_dias_365.query('not (6 <= `Día del año`.dt.month <=10)')

top_dias_ocupacion_sin_verano = sin_verano.head(20)
top_dias_ocupacion_sin_verano
# Out:
#     Día del año  Count
# 146  1900-05-28   3383
# 150  1900-05-27   3291
# 151  1900-04-30   3266
# 154  1900-05-29   3244
# 156  1900-04-15   3209
# 157  1900-05-26   3184
# 159  1900-05-30   3159
# 160  1900-05-31   3156
# 161  1900-04-14   3148
# 162  1900-04-16   3103
# 163  1900-12-31   3074
# 164  1900-04-08   3069
# 165  1900-05-25   3048
# 166  1900-05-22   3006
# 167  1900-04-29   3002
# 168  1900-04-07   3000
# 169  1900-04-20   2951
# 170  1900-05-23   2940
# 171  1900-04-13   2938
# 172  1900-05-21   2935

# %%
media_ocupacion = ocupacion_por_dias_365['Count'].mean()
media_ocupacion
# Out:
# 3793.5178082191783

# %%
combinado_meses_filtrado
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361764            ab-26982422   Rental unit  Entire home/apt         1
# 361765            ab-26982422   Rental unit  Entire home/apt         1
# 361769            ab-26982422   Rental unit  Entire home/apt         1
# 361773            ab-26982422   Rental unit  Entire home/apt         1
# 361775            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
columnas_a_media = ['Occupancy Rate', 'Overall Rating']
media_por_occ_y_OR = combinado_meses_filtrado.groupby('Property ID')[columnas_a_media].agg('mean')
media_por_occ_y_OR.columns = ['Occupancy Rate', 'Overall Rating']
media_por_occ_y_OR
# Out:
#                         Occupancy Rate  Overall Rating
# Property ID
# ab-10004778                   0.625000           100.0
# ab-1001311904372746789        1.000000             NaN
# ab-1002010433086291623        0.692000           100.0
# ab-1002116240004089156        0.364000             NaN
# ab-1002319445728837428        1.000000             NaN
# ...                                ...             ...
# ab-997017                     0.619333            90.0
# ab-997830448407748610         0.385000           100.0
# ab-998663395072348291         0.750000             NaN
# ab-999066356181901057         0.714000           100.0
# ab-999814483099845604         1.000000             NaN
#
# [12171 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.relplot(data = media_por_occ_y_OR, x = "Overall Rating", y = "Occupancy Rate", color='blue', alpha=0.5)
plt.title('Relación entre Overall Rating y Occupancy Rate')
plt.xlabel('Overall Rating')
plt.ylabel('Occupancy Rate')

ax = plt.gca()
ax.set_ylim(0.6,0.9)
ax.set_xlim(80,100)
plt.grid(True)  # Añadir cuadrícula al gráfico


plt.show()

# %%
combinado_meses_filtrado
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361764            ab-26982422   Rental unit  Entire home/apt         1
# 361765            ab-26982422   Rental unit  Entire home/apt         1
# 361769            ab-26982422   Rental unit  Entire home/apt         1
# 361773            ab-26982422   Rental unit  Entire home/apt         1
# 361775            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combin_purga_OR = combinado_meses_filtrado[combinado_meses_filtrado['Overall Rating'] > 10]
combin_purga_OR_y_ADR = combin_purga_OR[combin_purga_OR['ADR (Native)'] > 10]
columnas_a_media = ['ADR (Native)', 'Overall Rating']
media_por_ADR_y_OR = combin_purga_OR_y_ADR.groupby('Property ID')[columnas_a_media].agg('mean')
media_por_ADR_y_OR.columns = ['ADR (Native)', 'Overall Rating']
media_por_ADR_y_OR
# Out:
#                         ADR (Native)  Overall Rating
# Property ID
# ab-10004778                25.970000           100.0
# ab-1002010433086291623     27.560000           100.0
# ab-1003583041727761847     80.790000           100.0
# ab-10043593                43.787059            93.0
# ab-1006542280027852698    138.770000           100.0
# ...                              ...             ...
# ab-9952012                 32.660000           100.0
# ab-9954801                 37.278889            78.0
# ab-997017                  48.793333            90.0
# ab-997830448407748610      83.070000           100.0
# ab-999066356181901057     276.780000           100.0
#
# [7418 rows x 2 columns]

# %%
plt.figure(figsize=(8, 6))
sns.relplot(data = media_por_ADR_y_OR, x = "Overall Rating", y = "ADR (Native)", color='blue', alpha=0.5)
plt.title('Relación entre Overall Rating y Occupancy Rate')
plt.xlabel('Overall Rating')
plt.ylabel('ADR (Native)')
ax = plt.gca()
ax.set_ylim(10,1500)
ax.set_xlim(41,101)
plt.grid(True)  # Añadir cuadrícula al gráfico
plt.show()

# %%
dataframe_properties
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 1      ab-604957750694158984
# 2      ab-604966316637801053
# 3      ab-605014266200913335
# 4      ab-605108518012999409
# ...                      ...
# 13665            ab-37234059
# 13666            ab-38069101
# 13667            ab-23430781
# 13668            ab-18224445
# 13669            ab-40100070
#
#                                           Listing Title  Property Type  \
# 0         Stunning apartment in Torrevieja with kitchen    Rental unit
# 1      Stunning apartment in Torrevieja with 2 Bedrooms    Rental unit
# 2                      Precioso alojamiento con terraza  Vacation home
# 3          Precioso apartamento en complejo residencial          Condo
# 4                      ALQUILER VACACIONAL TORREVIEJA!!    Rental unit
# ...                                                 ...            ...
# 13665          Великолепная студия на первой линии моря    Rental unit
# ...

# %%
combin_purga_prop = dataframe_properties[dataframe_properties['Occupancy Rate LTM'] > 0]
combin_purga_prop = combin_purga_prop[combin_purga_prop['Number of Reviews'] > 0]
combin_purga_prop = combin_purga_prop[combin_purga_prop['Annual Revenue LTM (Native)'] > 10]
combin_purga_prop
# Out:
#                  Property ID  \
# 0      ab-604957749777772414
# 2      ab-604966316637801053
# 5      ab-605119030776239205
# 7      ab-605719787869931071
# 8      ab-606335499723450723
# ...                      ...
# 13642            ab-18805489
# 13648  ab-567333096428230967
# 13651            ab-42662570
# 13652            ab-33760547
# 13664            ab-45769328
#
#                                            Listing Title       Property Type  \
# 0          Stunning apartment in Torrevieja with kitchen         Rental unit
# 2                       Precioso alojamiento con terraza       Vacation home
# 5             Brand New Apartment. 400 meters Best Beach         Rental unit
# 7      1-bedroom w living room & corner sea-view terrace       Room in hotel
# 8         Cozy 2bdr Apartment, Between Two Beaches 300 m         Rental unit
# ...                                                  ...                 ...
# ...

# %%
plt.figure(figsize=(8, 6))
sns.relplot(data = combin_purga_prop, x = "Occupancy Rate LTM", y = "Number of Reviews", color='blue', alpha=0.5)
plt.title('Relación entre ocupación y número de reviews')
plt.xlabel('Tasa de ocupación')
plt.ylabel('Número de reviews')



plt.grid(True)  # Añadir cuadrícula al gráfico
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.relplot(data = combin_purga_prop, x = "Annual Revenue LTM (Native)", y = "Number of Reviews", color='blue', alpha=0.5)
plt.title('Relación entre ingresos y número de reviews')
plt.xlabel('Ingresos')
plt.ylabel('Número de reviews')
ax = plt.gca()
ax.set_ylim(0,150)
ax.set_xlim(1000,40000)


plt.grid(True)  # Añadir cuadrícula al gráfico
plt.show()

# %% [markdown]
# Modelo predictivo
#
# 1. Predicción de la ocupación futura
# 2. Optimización de precios

# %%
dataframe_por_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado_meses
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 1       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361785            ab-26982422   Rental unit  Entire home/apt         1
# 361786            ab-26982422   Rental unit  Entire home/apt         1
# 361787            ab-26982422   Rental unit  Entire home/apt         1
# 361788            ab-26982422   Rental unit  Entire home/apt         1
# 361789            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado_meses_filtrado
# Out:
#                   Property ID Property Type     Listing Type  Bedrooms  \
# 0       ab-604957749777772414   Rental unit  Entire home/apt         2
# 2       ab-604957749777772414   Rental unit  Entire home/apt         2
# 3       ab-604957749777772414   Rental unit  Entire home/apt         2
# 4       ab-604957749777772414   Rental unit  Entire home/apt         2
# 5       ab-604957749777772414   Rental unit  Entire home/apt         2
# ...                       ...           ...              ...       ...
# 361764            ab-26982422   Rental unit  Entire home/apt         1
# 361765            ab-26982422   Rental unit  Entire home/apt         1
# 361769            ab-26982422   Rental unit  Entire home/apt         1
# 361773            ab-26982422   Rental unit  Entire home/apt         1
# 361775            ab-26982422   Rental unit  Entire home/apt         1
#
#        Reporting Month  Occupancy Rate  Revenue (USD)  Revenue (Native)  \
# ...

# %%
combinado_meses_filtrado['Reporting Month'] = pd.to_datetime(combinado_meses_filtrado['Reporting Month'])
combinado_meses_filtrado['Mes'] = combinado_meses_filtrado['Reporting Month'].dt.month
# Out:
# <ipython-input-269-28430e6fcbd1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combinado_meses_filtrado['Reporting Month'] = pd.to_datetime(combinado_meses_filtrado['Reporting Month'])
# <ipython-input-269-28430e6fcbd1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combinado_meses_filtrado['Mes'] = combinado_meses_filtrado['Reporting Month'].dt.month

# %%
def asignar_temporada(mes):
    if mes in [6, 7, 8]:
        return "Alta"
    else:
        return "Baja"

# Aplicar la función a la columna "Mes" y crear la columna "Temporada"
combinado_meses_filtrado['Temporada'] = combinado_meses_filtrado['Mes'].apply(lambda mes: asignar_temporada(mes))
# Out:
# <ipython-input-270-a68618b28ee2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combinado_meses_filtrado['Temporada'] = combinado_meses_filtrado['Mes'].apply(lambda mes: asignar_temporada(mes))

# %%
combinado_meses_filtrado['Parking'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'free_parking' in x)
combinado_meses_filtrado['Piscina'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'pool' in x)
combinado_meses_filtrado['Aire Acondicionado'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'ac' in x)
combinado_meses_filtrado['Calefaccion'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'heating' in x)
combinado_meses_filtrado['TV'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'tv' in x)
combinado_meses_filtrado['Cocina'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'kitchen' in x)
combinado_meses_filtrado['Ascensor'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'elevator' in x)
combinado_meses_filtrado['Wifi'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'wireless_internet' in x)
# Out:
# <ipython-input-271-d7a0b82cac7e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combinado_meses_filtrado['Parking'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'free_parking' in x)
# <ipython-input-271-d7a0b82cac7e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combinado_meses_filtrado['Piscina'] = combinado_meses_filtrado['Amenities'].apply(lambda x: 'pool' in x)
# <ipython-input-271-d7a0b82cac7e>:3: SettingWithCopyWarning:
# ...

# %%
columnas_elimin = ['Property ID', 'Active', 'Airbnb Property ID', 'Airbnb Host ID', 'Listing Title','Amenities', 'Reporting Month', 'ADR (USD)', 'Number of Reservations', 'Available Days', 'Blocked Days', 'Latitude', 'Longitude', 'Revenue (USD)']
campos_anyadir2 = ['Property ID','Pets Allowed', 'Bathrooms', 'Number of Reviews', 'Airbnb Superhost', 'Exact Location', 'Instantbook Enabled']
columnas_a_anyadir2 = dataframe_properties.loc[:, campos_anyadir2]
combinado_meses_filtrado = pd.merge(combinado_meses_filtrado, columnas_a_anyadir2, on='Property ID', how = 'left')
combinado_meses_filtrado = combinado_meses_filtrado.drop(columns = columnas_elimin)

# %%
combinado_meses_filtrado
# Out:
#        Property Type     Listing Type  Bedrooms  Occupancy Rate  \
# 0        Rental unit  Entire home/apt         2           1.000
# 1        Rental unit  Entire home/apt         2           0.938
# 2        Rental unit  Entire home/apt         2           0.767
# 3        Rental unit  Entire home/apt         2           0.613
# 4        Rental unit  Entire home/apt         2           0.867
# ...              ...              ...       ...             ...
# 118742   Rental unit  Entire home/apt         1           0.611
# 118743   Rental unit  Entire home/apt         1           0.400
# 118744   Rental unit  Entire home/apt         1           0.217
# 118745   Rental unit  Entire home/apt         1           0.667
# 118746   Rental unit  Entire home/apt         1           0.333
#
#         Revenue (Native)  ADR (Native)  Reservation Days  Overall Rating  Mes  \
# 0                1703.35        212.92                 8           100.0    6
# ...

# %%
for col in combinado_meses_filtrado.select_dtypes(include = 'number').columns:
  combinado_meses_filtrado[col] = combinado_meses_filtrado[col].fillna(0)
for col in combinado_meses_filtrado.select_dtypes(include = 'object').columns:
  combinado_meses_filtrado[col] = combinado_meses_filtrado[col].fillna(combinado_meses_filtrado[col].mode()[0])

# %%
combinado_meses_filtrado
# Out:
#        Property Type     Listing Type  Bedrooms  Occupancy Rate  \
# 0        Rental unit  Entire home/apt         2           1.000
# 1        Rental unit  Entire home/apt         2           0.938
# 2        Rental unit  Entire home/apt         2           0.767
# 3        Rental unit  Entire home/apt         2           0.613
# 4        Rental unit  Entire home/apt         2           0.867
# ...              ...              ...       ...             ...
# 118742   Rental unit  Entire home/apt         1           0.611
# 118743   Rental unit  Entire home/apt         1           0.400
# 118744   Rental unit  Entire home/apt         1           0.217
# 118745   Rental unit  Entire home/apt         1           0.667
# 118746   Rental unit  Entire home/apt         1           0.333
#
#         Revenue (Native)  ADR (Native)  Reservation Days  Overall Rating  Mes  \
# 0                1703.35        212.92                 8           100.0    6
# ...

# %%
combinado_mf_sin_nan = combinado_meses_filtrado.copy()

# %%
X = combinado_mf_sin_nan.drop(columns=['ADR (Native)'])
y = combinado_mf_sin_nan['ADR (Native)']

# %%
X
# Out:
#        Property Type     Listing Type  Bedrooms  Occupancy Rate  \
# 0        Rental unit  Entire home/apt         2           1.000
# 1        Rental unit  Entire home/apt         2           0.938
# 2        Rental unit  Entire home/apt         2           0.767
# 3        Rental unit  Entire home/apt         2           0.613
# 4        Rental unit  Entire home/apt         2           0.867
# ...              ...              ...       ...             ...
# 118742   Rental unit  Entire home/apt         1           0.611
# 118743   Rental unit  Entire home/apt         1           0.400
# 118744   Rental unit  Entire home/apt         1           0.217
# 118745   Rental unit  Entire home/apt         1           0.667
# 118746   Rental unit  Entire home/apt         1           0.333
#
#         Revenue (Native)  Reservation Days  Overall Rating  Mes Temporada  \
# 0                1703.35                 8           100.0    6      Alta
# ...

# %%
y
# Out:
# 0         212.92
# 1         300.41
# 2         287.44
# 3         272.21
# 4         260.74
#            ...
# 118742     60.41
# 118743     69.75
# 118744     43.75
# 118745     63.34
# 118746    146.33
# Name: ADR (Native), Length: 118747, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
X_encoded = X.copy()
encoder_property_type = LabelEncoder()
encoder_listing_type = LabelEncoder()
encoder_pets_allowed = LabelEncoder()
encoder_superhost = LabelEncoder()
encoder_mes = LabelEncoder()

encoder_exact_location = LabelEncoder()
encoder_instantbook_enabled = LabelEncoder()
encoder_temporada = LabelEncoder()


encoder_parking = LabelEncoder()
encoder_piscina = LabelEncoder()
encoder_ac = LabelEncoder()
encoder_calefacc = LabelEncoder()
encoder_tv = LabelEncoder()
encoder_cocina = LabelEncoder()
encoder_ascensor = LabelEncoder()
encoder_wifi = LabelEncoder()




X_encoded['Parking'] = encoder_parking.fit_transform(X['Parking'])
X_encoded['Piscina'] = encoder_piscina.fit_transform(X['Piscina'])
X_encoded['Aire Acondicionado'] = encoder_ac.fit_transform(X['Aire Acondicionado'])
X_encoded['Calefaccion'] = encoder_calefacc.fit_transform(X['Calefaccion'])
X_encoded['TV'] = encoder_tv.fit_transform(X['TV'])
X_encoded['Cocina'] = encoder_cocina.fit_transform(X['Cocina'])
X_encoded['Ascensor'] = encoder_ascensor.fit_transform(X['Ascensor'])
X_encoded['Wifi'] = encoder_wifi.fit_transform(X['Wifi'])




X_encoded['Temporada'] = encoder_temporada.fit_transform(X['Temporada'])
X_encoded['Mes'] = encoder_mes.fit_transform(X['Mes'])
X_encoded['Property Type'] = encoder_property_type.fit_transform(X['Property Type'])
X_encoded['Listing Type'] = encoder_listing_type.fit_transform(X['Listing Type'])
X_encoded['Pets Allowed'] = encoder_pets_allowed.fit_transform(X['Pets Allowed'])
X_encoded['Airbnb Superhost'] = encoder_superhost.fit_transform(X['Airbnb Superhost'])

X_encoded['Exact Location'] = encoder_exact_location.fit_transform(X['Exact Location'])
X_encoded['Instantbook Enabled'] = encoder_instantbook_enabled.fit_transform(X['Instantbook Enabled'])

# %%
X_encoded
# Out:
#         Property Type  Listing Type  Bedrooms  Occupancy Rate  \
# 0                  43             0         2           1.000
# 1                  43             0         2           0.938
# 2                  43             0         2           0.767
# 3                  43             0         2           0.613
# 4                  43             0         2           0.867
# ...               ...           ...       ...             ...
# 118742             43             0         1           0.611
# 118743             43             0         1           0.400
# 118744             43             0         1           0.217
# 118745             43             0         1           0.667
# 118746             43             0         1           0.333
#
#         Revenue (Native)  Reservation Days  Overall Rating  Mes  Temporada  \
# 0                1703.35                 8           100.0    5          0
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# Copia del DataFrame original
X_enc = X.copy()

# Inicializar OneHotEncoder

encoder_property_type = OneHotEncoder()
encoder_listing_type = OneHotEncoder()
encoder_pets_allowed = OneHotEncoder()
encoder_superhost = OneHotEncoder()
encoder_mes = OneHotEncoder()
encoder_cancellation = OneHotEncoder()
encoder_exact_location = OneHotEncoder()
encoder_instantbook_enabled = OneHotEncoder()
encoder_temporada = OneHotEncoder()


encoder_parking = OneHotEncoder()
encoder_piscina = OneHotEncoder()
encoder_ac = OneHotEncoder()
encoder_calefacc = OneHotEncoder()
encoder_tv = OneHotEncoder()
encoder_cocina = OneHotEncoder()
encoder_ascensor = OneHotEncoder()
encoder_wifi = OneHotEncoder()



# Transformar cada columna categórica y añadir las nuevas columnas al DataFrame
X_enc = pd.concat([
    X,
    pd.DataFrame(encoder_mes.fit_transform(X[['Mes']]).toarray(), columns=encoder_mes.get_feature_names_out(['Mes'])),
    pd.DataFrame(encoder_mes.fit_transform(X[['Temporada']]).toarray(), columns=encoder_mes.get_feature_names_out(['Temporada'])),
    pd.DataFrame(encoder_property_type.fit_transform(X[['Property Type']]).toarray(), columns=encoder_property_type.get_feature_names_out(['Property Type'])),
    pd.DataFrame(encoder_listing_type.fit_transform(X[['Listing Type']]).toarray(), columns=encoder_listing_type.get_feature_names_out(['Listing Type'])),
    pd.DataFrame(encoder_pets_allowed.fit_transform(X[['Pets Allowed']]).toarray(), columns=encoder_pets_allowed.get_feature_names_out(['Pets Allowed'])),
    pd.DataFrame(encoder_superhost.fit_transform(X[['Airbnb Superhost']]).toarray(), columns=encoder_superhost.get_feature_names_out(['Airbnb Superhost'])),
    pd.DataFrame(encoder_exact_location.fit_transform(X[['Exact Location']]).toarray(), columns=encoder_exact_location.get_feature_names_out(['Exact Location'])),
    pd.DataFrame(encoder_instantbook_enabled.fit_transform(X[['Instantbook Enabled']]).toarray(), columns=encoder_instantbook_enabled.get_feature_names_out(['Instantbook Enabled'])),



    pd.DataFrame(encoder_parking.fit_transform(X[['Parking']]).toarray(), columns=encoder_parking.get_feature_names_out(['Parking'])),
    pd.DataFrame(encoder_piscina.fit_transform(X[['Piscina']]).toarray(), columns=encoder_piscina.get_feature_names_out(['Piscina'])),
    pd.DataFrame(encoder_ac.fit_transform(X[['Aire Acondicionado']]).toarray(), columns=encoder_ac.get_feature_names_out(['Aire Acondicionado'])),
    pd.DataFrame(encoder_calefacc.fit_transform(X[['Calefaccion']]).toarray(), columns=encoder_calefacc.get_feature_names_out(['Calefaccion'])),
    pd.DataFrame(encoder_tv.fit_transform(X[['TV']]).toarray(), columns=encoder_tv.get_feature_names_out(['TV'])),
    pd.DataFrame(encoder_cocina.fit_transform(X[['Cocina']]).toarray(), columns=encoder_cocina.get_feature_names_out(['Cocina'])),
    pd.DataFrame(encoder_ascensor.fit_transform(X[['Ascensor']]).toarray(), columns=encoder_ascensor.get_feature_names_out(['Ascensor'])),
    pd.DataFrame(encoder_wifi.fit_transform(X[['Wifi']]).toarray(), columns=encoder_wifi.get_feature_names_out(['Wifi']))






], axis=1)

# Eliminar las columnas categóricas originales del DataFrame
X_enc.drop(['Parking', 'Piscina', 'Aire Acondicionado', 'Calefaccion', 'TV', 'Cocina', 'Ascensor', 'Wifi', 'Mes', 'Temporada', 'Property Type', 'Listing Type', 'Pets Allowed', 'Airbnb Superhost', 'Exact Location', 'Instantbook Enabled'], axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_enc, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse
# Out:
# 1614.0761474498943

# %%
r2
# Out:
# 0.6558735386564092

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([40.96642856, 63.63702584, 64.1558912 , ..., 82.02978918,
#        39.80755112, 79.65422448])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

param_grid = {'alpha': [0.1, 1.0, 10.0]}

# Inicializar el modelo
model = Ridge()

# Configurar la búsqueda de cuadrícula con validación cruzada
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')

# Realizar la búsqueda de cuadrícula
grid_search.fit(X_train, y_train)

# Obtener el mejor modelo y los mejores hiperparámetros
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

# Evaluar el modelo final en el conjunto de prueba
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = best_model.score(X_test, y_test)

print("Mejores hiperparámetros:", best_params)
print("Error cuadrático medio:", mse)
print("R^2:", r2)
# Out:
# Mejores hiperparámetros: {'alpha': 1.0}
# Error cuadrático medio: 1614.002653391939
# R^2: 0.6558892078366605

# %%
best_model
# Out:
# Ridge()

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_enc, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-290-f3fec3bc9f9d> in <cell line: 5>()
#       3 from sklearn.model_selection import train_test_split
#       4 X_train, X_test, y_train, y_test = train_test_split(X_enc, y, test_size=0.2, random_state=42)
# ----> 5 model.fit(X_train, y_train)
#       6 y_pred = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     471             # parallel_backend contexts set at a higher level,
#     472             # since correctness does not rely on using threads.
# --> 473             trees = Parallel(
#     474                 n_jobs=self.n_jobs,
#     475                 verbose=self.verbose,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
# ...

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse

# %%
r2

# %% [markdown]
# XGBREGRESSOR

# %%
from xgboost import XGBRegressor

X_train, X_test, y_train, y_test = train_test_split(X_enc, y, test_size=0.2, random_state=42)
xgb_reg = XGBRegressor()
xgb_reg.fit(X_train, y_train)

y_pred = xgb_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 111.52164291345476
# R^2 Score: 0.9762232107824256

# %%
y_pred_df = pd.DataFrame(y_pred, columns=['Predicción'])
X_test_pred = pd.concat([X_test.reset_index(drop=True), y_pred_df], axis=1)
X_test_pred
# Out:
#        Bedrooms  Occupancy Rate  Revenue (Native)  Reservation Days  \
# 0             1           1.000            446.54                13
# 1             2           0.586           1140.08                17
# 2             1           0.500            704.85                11
# 3             2           0.968           1166.82                30
# 4             1           0.290            532.58                 9
# ...         ...             ...               ...               ...
# 23745         1           0.516           1544.57                16
# 23746         1           0.038             25.33                 1
# 23747         2           0.267            459.30                 8
# 23748         1           0.633            795.82                19
# 23749         2           0.286            434.48                 8
#
#        Overall Rating  Bathrooms  Number of Reviews  Mes_1  Mes_2  Mes_3  ...  \
# ...
